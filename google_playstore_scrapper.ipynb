# %% [markdown]
# Download library

# %%
# !pip install google-play-scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %% [markdown]
# SCRAPE ALL

# %%
# Scrape All available reviews 
#(DONT RUN THIS CELL!!! IF YOU DONT WANT TO SCRAPE ALL REVIEWS)

from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'com.linkdokter.halodoc.android',
    sleep_milliseconds=0, # defaults to 0
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT , you can use Sort.NEWEST to get newst reviews
)

# %% [markdown]
# SCRAPE TO

# %%
#Scrape desired number of reviews

from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'gov.dukcapil.mobile_id',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
    count=1200, # defaults to 100
    filter_score_with=None # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %%
df_data = pd.DataFrame(np.array(result),columns=['review'])

df_data = df_data.join(pd.DataFrame(df_data.pop('review').tolist()))

df_data.head()
# Out:
#                                reviewId            userName  \
# 0  1d74e3b0-9ebd-4fae-9ecc-d9d133fc47ff          Miss Queen
# 1  842637c7-6d96-4ab6-94af-230da3a89eee      Benny Johannes
# 2  4a8e3c7b-30a7-41c7-913f-7eb15df1b9a8      ENDANG LESTARI
# 3  ca9ffd74-6144-4ed4-b037-e38793ac9c80  Team Mobile Legend
# 4  8daedf90-8afd-43ef-84d1-f85ce3dead49           ily andhi
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AAcHTt...
# 1  https://play-lh.googleusercontent.com/a-/AD_cM...
# 2  https://play-lh.googleusercontent.com/a-/AD_cM...
# 3  https://play-lh.googleusercontent.com/a/AAcHTt...
# 4  https://play-lh.googleusercontent.com/a-/AD_cM...
#
#                                              content  score  thumbsUpCount  \
# 0  apk dibuka tulisanya konektifitas bermasalah c...      1             24
# 1  Mohon info donk, kenapa buka dokument selalu m...      5             11
# ...

# %%
len(df_data.index) #count the number of data we got
# Out:
# 10000

# %%
df_data[['userName', 'score','at', 'content']].head()  #preview userName, rating, date-time, and reviews only
# Out:
#              userName  score                  at  \
# 0          Miss Queen      1 2023-05-24 12:45:21
# 1      Benny Johannes      5 2023-05-24 09:21:05
# 2      ENDANG LESTARI      1 2023-05-26 08:46:35
# 3  Team Mobile Legend      1 2023-05-22 02:07:02
# 4           ily andhi      1 2023-05-26 03:42:23
#
#                                              content
# 0  apk dibuka tulisanya konektifitas bermasalah c...
# 1  Mohon info donk, kenapa buka dokument selalu m...
# 2  Kenapa di file dokumen,yang terlihat hanya KTP...
# 3  Sebelum membuat kebijakan cek dulu kesiapannya...
# 4  Katanya Aplikasi Identitas Kependudukan Digita...

# %%
#Run This Code to Sort the Data By Date 

new_df = df_data[['userName', 'score','at', 'content']]
sorted_df = new_df.sort_values(by='at', ascending=False) #Sort by Newst, change to True if you want to sort by Oldest.
sorted_df.head()
# Out:
#                 userName  score                  at  \
# 7779       Ajat Sudrajat      1 2023-05-27 12:48:14
# 7778        Yosua Wijaya      2 2023-05-27 07:19:44
# 7780     Novita Khasanah      1 2023-05-27 03:27:19
# 7782         Rika Fitria      1 2023-05-27 03:26:49
# 7776  Akatsuki Maftukhan      2 2023-05-27 02:11:14
#
#                                                 content
# 7779  mohon penjelasannya dong sayamasuk aplikasi KT...
# 7778  Sama saja harus datang ke dukcapil gak hemat w...
# 7780  Tips plis dong kak cara mengatasi lupa pin/san...
# 7782                                            apk jlk
# 7776  Aplikasi lelet banget, sering bug buka dokumen...

# %%
my_df = sorted_df[['userName', 'score','at', 'content']] #get userName, rating, date-time, and reviews only

# %%
my_df.head()
# Out:
#                 userName  score                  at  \
# 7779       Ajat Sudrajat      1 2023-05-27 12:48:14
# 7778        Yosua Wijaya      2 2023-05-27 07:19:44
# 7780     Novita Khasanah      1 2023-05-27 03:27:19
# 7782         Rika Fitria      1 2023-05-27 03:26:49
# 7776  Akatsuki Maftukhan      2 2023-05-27 02:11:14
#
#                                                 content
# 7779  mohon penjelasannya dong sayamasuk aplikasi KT...
# 7778  Sama saja harus datang ke dukcapil gak hemat w...
# 7780  Tips plis dong kak cara mengatasi lupa pin/san...
# 7782                                            apk jlk
# 7776  Aplikasi lelet banget, sering bug buka dokumen...

# %%
my_df.to_csv("DATASET.csv", index = False)  #Save the file as CSV , to download: click the folder icon on the left. the csv file should be there.
